# %% [markdown]
# # Exploratory Data Analysis
# My Dataset :https://view.officeapps.live.com/op/view.aspx?src=https%3A%2F%2Fcdn-assets.theforage.com%2Fvinternship_modules%2Fkpmg_data_analytics%2FKPMG_VI_New_raw_data_update_final.xlsx&wdOrigin=BROWSELINK

# %% [markdown]
# # Business Issue
# Sprocket Central Pty Ltd needs help with its customer and transactions data. The organisation has a large dataset relating to its customers, but their team is unsure how to effectively analyse it to help optimise its marketing strategy.

# %% [markdown]
# # Import

# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Create New DataFrames

# %%
# Read the Excel file
file_path = r"C:\Users\chand\Launchcode\KPMG\KPMG_VI_New_raw_data_update_final1.xlsx"
xls = pd.ExcelFile(file_path)

# Read specific sheets into DataFrames
df1 = pd.read_excel(xls, sheet_name='Transactions')

# Close the ExcelFile object
xls.close()

df1
#df2
#df3
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
# Read the Excel file
file_path = r"C:\Users\chand\Launchcode\KPMG\KPMG_VI_New_raw_data_update_final1.xlsx"
xls = pd.ExcelFile(file_path)

# # Define column data types
column_data_types = {
    'DateColumn': str,  # Replace 'DateColumn' with the actual column name
    # Add more columns with their appropriate data types if needed
}

# Read specific sheet into DataFrame with specified data types
df2 = pd.read_excel(xls, sheet_name='CustomerDemographic')

# Close the ExcelFile object
xls.close()
df2
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_50080\1615316481.py:12: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df2 = pd.read_excel(xls, sheet_name='CustomerDemographic')
#       customer_id first_name  last_name  gender  \
# 0              34   Jephthah   Bachmann       U
# 1              66     Anselm      Gawne    Male
# 2            1888      Sibyl    Scholtz  Female
# 3            3435    Stevena    Allcock  Female
# 4            2858  Benedicto      Radki    Male
# ...           ...        ...        ...     ...
# 3995         3779      Ulick     Daspar       U
# 3996         3883      Nissa     Conrad       U
# 3997         3931      Kylie      Epine       U
# 3998         3935     Teodor  Alfonsini       U
# 3999         3998     Sarene    Woolley       U
#
# ...

# %%
# Read the Excel file
file_path = r"C:\Users\chand\Launchcode\KPMG\KPMG_VI_New_raw_data_update_final1.xlsx"
xls = pd.ExcelFile(file_path)

# Read specific sheet into DataFrame with specified data types
df3 = pd.read_excel(xls, sheet_name='CustomerAddress')

# Close the ExcelFile object
xls.close()

df3
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %% [markdown]
# # Dataframe Info

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB
# None

# %% [markdown]
# # Show First Five Rows

# %%
df1.head(5)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df2.head(5)
# Out:
#    customer_id first_name last_name  gender  \
# 0           34   Jephthah  Bachmann       U
# 1           66     Anselm     Gawne    Male
# 2         1888      Sibyl   Scholtz  Female
# 3         3435    Stevena   Allcock  Female
# 4         2858  Benedicto     Radki    Male
#
#    past_3_years_bike_related_purchases        DOB           job_title  \
# 0                                   59 1843-12-21     Legal Assistant
# 1                                   46 2002-03-11   Account Executive
# 2                                   67 2002-01-26        Food Chemist
# 3                                   80 2002-01-15       Senior Editor
# 4                                    4 2002-01-09  Recruiting Manager
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                    IT  Affluent Customer                  N
# 1           Argiculture     High Net Worth                  N
# 2                Health      Mass Customer                  N
# ...

# %%
df3.head(5)
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %% [markdown]
# # Groupby Transaction id for the first five rows

# %%
df1.groupby('transaction_id').first(5)
# Out:
#                 product_id  customer_id  online_order  list_price  \
# transaction_id
# 1                        2         2950           0.0       71.49
# 2                        3         3120           1.0     2091.47
# 3                       37          402           0.0     1793.43
# 4                       88         3135           0.0     1198.46
# 5                       78          787           1.0     1765.30
# ...                    ...          ...           ...         ...
# 19996                   51         1018           1.0     2005.66
# 19997                   41          127           1.0      416.98
# 19998                   87         2284           1.0     1636.90
# 19999                    6         2764           0.0      227.88
# 20000                   11         1144           1.0     1775.81
#
#                 standard_cost  product_first_sold_date
# transaction_id
# 1                       53.62                  41245.0
# ...

# %% [markdown]
# # Groupby Customer id for the first five rows

# %%
df2.groupby('customer_id').first(5)
# Out:
#              past_3_years_bike_related_purchases  tenure
# customer_id
# 1                                             93    11.0
# 2                                             81    16.0
# 3                                             61    15.0
# 4                                             33     7.0
# 5                                             56     8.0
# ...                                          ...     ...
# 3996                                           8    19.0
# 3997                                          87     1.0
# 3998                                          60     NaN
# 3999                                          11    10.0
# 4000                                          76    11.0
#
# [4000 rows x 2 columns]

# %% [markdown]
# # Groupby Customer id for the first five rows

# %%
df3.groupby('customer_id').first(5)
# Out:
#              postcode  property_valuation
# customer_id
# 1                2016                  10
# 2                2153                  10
# 4                4211                   9
# 5                2448                   4
# 6                3216                   9
# ...               ...                 ...
# 3999             3064                   3
# 4000             4511                   6
# 4001             2756                  10
# 4002             4032                   7
# 4003             2251                   7
#
# [3999 rows x 2 columns]

# %% [markdown]
# # Check how many rows and columns are present

# %%
df1.shape
# Out:
# (20000, 13)

# %%
df2.shape
# Out:
# (4000, 13)

# %%
df3.shape
# Out:
# (3999, 6)

# %% [markdown]
# # Get column names

# %%
df1.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['customer_id', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %% [markdown]
# # Find null values
#
# df1 = online_order - 360, brand - 197, product_line - 197, product_class - 197, product_size - 197, standard_cost - 197, product_first_sold_date - 197

# %%
df1.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %% [markdown]
# df2 = last_name - 125, DOB - 87, job_title - 506, job_industry_category - 656, default - 302, tenure - 87

# %%
df2.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %% [markdown]
# # Getting categorial columns

# %%
categorial_cols1 = df1.select_dtypes(exclude='number').columns.to_list()

print('Categorical Columns: ', categorial_cols1)
# Out:
# Categorical Columns:  ['transaction_date', 'order_status', 'brand', 'product_line', 'product_class', 'product_size']

# %%
categorial_cols2 = df2.select_dtypes(exclude='number').columns.to_list()

print('Categorical Columns: ', categorial_cols2)
# Out:
# Categorical Columns:  ['first_name', 'last_name', 'gender', 'DOB', 'job_title', 'job_industry_category', 'wealth_segment', 'deceased_indicator', 'default', 'owns_car']

# %%
categorial_cols3 = df3.select_dtypes(exclude='number').columns.to_list()

print('Categorical Columns: ', categorial_cols3)
# Out:
# Categorical Columns:  ['address', 'state', 'country']

# %% [markdown]
# # Exploring categorial columns

# %%
for col in categorial_cols1:
    print('-----------------------------')
    print('Series: ', col)
    print('-----------------------------')
    print(df1[col].value_counts())
    print('\n')
# Out:
# -----------------------------
# Series:  transaction_date
# -----------------------------
# 2017-02-14    82
# 2017-08-18    82
# 2017-10-15    76
# 2017-01-31    73
# 2017-12-19    71
#               ..
# 2017-01-12    38
# 2017-12-07    37
# 2017-03-29    36
# 2017-09-25    35
# 2017-10-19    32
# Name: transaction_date, Length: 364, dtype: int64
#
#
# -----------------------------
# Series:  order_status
# -----------------------------
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64
#
#
# -----------------------------
# Series:  brand
# -----------------------------
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64
#
#
# -----------------------------
# Series:  product_line
# -----------------------------
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64
#
#
# ...

# %% [markdown]
# Notes:
#
# df1 dataset contains 20000 datapoints(rows) and 13 features (columns). Some features presents null values. There are no duplicates.
#
# _Transaction Date : The dataset seems to cover transactions throughout the year 2017. Some dates like 2017-02-14 and 2017-08-18 have higher transanction frequencies - 82, indicating certain periods of activity.
#
# _Order Status: The majority of orders are labled as approved and only small number of orders are labled as canceled.
#
# _Brand : The "Solex-4253" brand has the highest frequency, followed by "Giant Bicycles-3312" and "WeareA2B-3295."
# "Norco Bicycles-2910" has the lowest frequency among the listed brands.
#
# _Product_line : "Standard-14176" has the higher frequency followed by "Road-3970" and "Touring-1234". "Mountain-423" has the lowest frequency.
#
# _Product Class : The majority of the product falls under "Medium" class, A significant number of products falls under "High" and "low" class as well.
#
# _Product size : The majority of the product falls under "Medium" size, "Large" and "small" sizes falls have lower frequencies.

# %%
for col in categorial_cols2:
    print('-----------------------------')
    print('Series: ', col)
    print('-----------------------------')
    print(df2[col].value_counts())
    print('\n')
# Out:
# -----------------------------
# Series:  first_name
# -----------------------------
# Max        5
# Timmie     5
# Tobe       5
# Osgood     4
# Basile     4
#           ..
# Tamarah    1
# Araldo     1
# Whitby     1
# Sherm      1
# Sarene     1
# Name: first_name, Length: 3139, dtype: int64
#
#
# -----------------------------
# Series:  last_name
# -----------------------------
# Pristnor     3
# Ramsdell     3
# Ortler       2
# Crack        2
# Carren       2
#             ..
# Kernes       1
# Saiger       1
# Dumbelton    1
# Prover       1
# Woolley      1
# Name: last_name, Length: 3725, dtype: int64
#
#
# -----------------------------
# Series:  gender
# -----------------------------
# Female    2037
# Male      1872
# U           88
# M            1
# Femal        1
# F            1
# Name: gender, dtype: int64
#
#
# -----------------------------
# Series:  DOB
# -----------------------------
# 1978-01-30    7
# 1978-08-19    4
# 1962-12-17    4
# 1976-09-25    4
# ...

# %% [markdown]
# Notes:
#
# _First Name and Last Name:
#
# There is a variety of unique first and last names in the dataset.
# Some names appear multiple times, suggesting possible duplicates or multiple customers with the same name.
#
# _Gender:
#
# The "Female" gender is slightly more common than "Male."
# There are a few entries with non-standard gender labels like "U," "M," "Femal," and "F". It shows inconsistency of this column will correct it in data cleaning.
#
# _Date of Birth (DOB):
#
# There is a range of birthdates in the dataset.
# Some birthdates appear multiple times, indicating that multiple customers share the same birthdate. there should be an typo error in DOB appears incorrect.
#
# _Job Title:
#
# The dataset includes various job titles, with some appearing more frequently than others.
# The most common job titles include "Business Systems Development Analyst," "Social Worker," and "Tax Accountant."
#
# _Job Industry Category:
#
# The dataset covers various job industries, with "Manufacturing" and "Financial Services" being the most common.
# Some job industries appear more frequently than others.
#
# _Wealth Segment:
#
# The "Mass Customer" wealth segment is the most common, followed by "High Net Worth" and "Affluent Customer."
#
# _Deceased Indicator:
#
# The majority of customers are marked as "N" (not deceased), with only a small number marked as "Y" (deceased).
#
# _Default:
#
# The "default" column contains a variety of values, including numbers, special characters, and text.
# Some entries have high frequency counts, suggesting certain default values are more common.
#
# _Owns Car:
#
# The dataset has a relatively balanced distribution between customers who own a car ("Yes") and those who don't ("No").

# %%
for col in categorial_cols3:
    print('-----------------------------')
    print('Series: ', col)
    print('-----------------------------')
    print(df3[col].value_counts())
    print('\n')
# Out:
# -----------------------------
# Series:  address
# -----------------------------
# 3 Mariners Cove Terrace      2
# 3 Talisman Place             2
# 64 Macpherson Junction       2
# 359 Briar Crest Road         1
# 4543 Service Terrace         1
#                             ..
# 5063 Shopko Pass             1
# 09 Hagan Pass                1
# 87897 Lighthouse Bay Pass    1
# 294 Lawn Junction            1
# 320 Acker Drive              1
# Name: address, Length: 3996, dtype: int64
#
#
# -----------------------------
# Series:  state
# -----------------------------
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64
#
#
# -----------------------------
# Series:  country
# -----------------------------
# Australia    3999
# Name: country, dtype: int64

# %% [markdown]
# Notes :
#
# Address:
#
# Multiple addresses appear more than once, suggesting the possibility of duplicate entries or multiple customers sharing the same address.
# Some addresses, like "3 Mariners Cove Terrace," "3 Talisman Place," and "64 Macpherson Junction," appear twice.
#
# State:
#
# The dataset includes multiple states with different spellings ("NSW," "VIC," "QLD," "New South Wales," "Victoria").
# Standardizing state labels to a consistent format ("NSW," "VIC," "QLD") could improve data quality.
#
# Country:
#
# The dataset contains customers from a single country: "Australia."
# These findings provide insights into the distribution of categorical variables related to addresses, states, and countries. It's essential to review and potentially clean up the data to ensure consistency in labels, handle duplicates, and maintain data quality for further analysis or modeling.

# %%
df1['product_first_sold_date'].dtype
df1['product_first_sold_date'].unique()

# Assuming df1 is your DataFrame and 'Product First Sold Date' is the column name
# Define the reference date (adjust as needed)
reference_date = pd.to_datetime('1900-01-01')

# Convert the numeric values to datetime
df1['time_difference'] = df1['product_first_sold_date'] - df1['transaction_date']
#df1['product_first_sold_date'] = reference_date + pd.to_timedelta(df1['product_first_sold_date'], unit='D')
df1
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
numerical_cols = df1.select_dtypes(include='number').columns.to_list()

print('Numerical Columns: ', numerical_cols)
# Out:
# Numerical Columns:  ['transaction_id', 'product_id', 'customer_id', 'online_order', 'list_price', 'standard_cost', 'product_first_sold_date']

# %%
numerical_cols1 = df2.select_dtypes(include='number').columns.to_list()

print('Numerical Columns: ', numerical_cols1)
# Out:
# Numerical Columns:  ['customer_id', 'past_3_years_bike_related_purchases', 'tenure']

# %%
numerical_cols2 = df3.select_dtypes(include='number').columns.to_list()

print('Numerical Columns: ', numerical_cols2)
# Out:
# Numerical Columns:  ['customer_id', 'postcode', 'property_valuation']

# %%
for num in numerical_cols:
    print('-----------------------------')
    print('Series: ', num)
    print('-----------------------------')
    print(df1[num].describe())
    print('\n')
# Out:
# -----------------------------
# Series:  transaction_id
# -----------------------------
# count    20000.000000
# mean     10000.500000
# std       5773.647028
# min          1.000000
# 25%       5000.750000
# 50%      10000.500000
# 75%      15000.250000
# max      20000.000000
# Name: transaction_id, dtype: float64
#
#
# -----------------------------
# Series:  product_id
# -----------------------------
# count    20000.00000
# mean        45.36465
# std         30.75359
# min          0.00000
# 25%         18.00000
# 50%         44.00000
# 75%         72.00000
# max        100.00000
# Name: product_id, dtype: float64
#
#
# -----------------------------
# Series:  customer_id
# -----------------------------
# count    20000.000000
# mean      1738.246050
# std       1011.951046
# min          1.000000
# 25%        857.750000
# 50%       1736.000000
# 75%       2613.000000
# max       5034.000000
# Name: customer_id, dtype: float64
#
#
# -----------------------------
# ...

# %% [markdown]
# Notes:
#
# Transaction ID:
#
# There are a total of 20,000 transactions.
# Transaction IDs range from 1 to 20,000.
# The mean transaction ID is 10,000.5, which suggests a fairly uniform distribution.
#
# Product ID:
#
# There are a total of 20,000 product IDs.
# Product IDs range from 0 to 100.
# The mean product ID is approximately 45.4, indicating that product IDs are relatively evenly distributed.
#
# Customer ID:
#
# There are a total of 20,000 customer IDs.
# Customer IDs range from 1 to 5,034.
# The mean customer ID is approximately 1,738.2.
#
# Online Order:
#
# There are 19,640 records with information about online orders.
# Online order values are binary, with 0 indicating no online order and 1 indicating an online order.
# On average, online orders are nearly evenly split, with a mean of approximately 0.5.
#
# List Price:
#
# The list price of products ranges from $12.01 to $2,091.47.
# The mean list price is approximately $1,107.83.
# The standard deviation suggests some variability in list prices.
#
# Standard Cost:
#
# The standard cost of products ranges from $7.21 to $1,759.85.
# The mean standard cost is approximately $556.05.
# The standard deviation indicates some variability in standard costs.
#
# Product First Sold Date:
#
# The column contains 19,803 non-null datetime values.
# There are 100 unique datetime values.
# The most frequent (mode) datetime value is '1992-10-04 00:00:00', which appears 234 times in the column.
# The earliest datetime value is '1991-01-23 00:00:00'.
# The latest datetime value is '2016-12-08 00:00:00'.

# %%
for num in numerical_cols1:
    print('-----------------------------')
    print('Series: ', num)
    print('-----------------------------')
    print(df2[num].describe())
    print('\n')
# Out:
# -----------------------------
# Series:  customer_id
# -----------------------------
# count    4000.000000
# mean     2000.500000
# std      1154.844867
# min         1.000000
# 25%      1000.750000
# 50%      2000.500000
# 75%      3000.250000
# max      4000.000000
# Name: customer_id, dtype: float64
#
#
# -----------------------------
# Series:  past_3_years_bike_related_purchases
# -----------------------------
# count    4000.000000
# mean       48.890000
# std        28.715005
# min         0.000000
# 25%        24.000000
# 50%        48.000000
# 75%        73.000000
# max        99.000000
# Name: past_3_years_bike_related_purchases, dtype: float64
#
#
# -----------------------------
# Series:  tenure
# -----------------------------
# count    3913.000000
# mean       10.657041
# std         5.660146
# min         1.000000
# 25%         6.000000
# 50%        11.000000
# 75%        15.000000
# max        22.000000
# Name: tenure, dtype: float64

# %% [markdown]
# Notes:
#
# Customer ID (customer_id):
#
# Count: 4,000 entries.
# Mean (average) customer ID: 2,000.5.
# Standard deviation: 1,154.84.
# Minimum customer ID: 1.
# Maximum customer ID: 4,000.
#
# Past 3 Years Bike-Related Purchases (past_3_years_bike_related_purchases):
#
# Count: 4,000 entries.
# Mean (average) bike-related purchases in the past 3 years: 48.89.
# Standard deviation: 28.72.
# Minimum purchases: 0.
# Maximum purchases: 99.
#
# Tenure (tenure):
#
# Count: 3,913 entries.
# Mean (average) tenure: 10.66 years.
# Standard deviation: 5.66 years.
# Minimum tenure: 1 year.
# Maximum tenure: 22 years.

# %%
for num in numerical_cols2:
    print('-----------------------------')
    print('Series: ', num)
    print('-----------------------------')
    print(df3[num].describe())
    print('\n')
# Out:
# -----------------------------
# Series:  customer_id
# -----------------------------
# count    3999.000000
# mean     2003.987997
# std      1154.576912
# min         1.000000
# 25%      1004.500000
# 50%      2004.000000
# 75%      3003.500000
# max      4003.000000
# Name: customer_id, dtype: float64
#
#
# -----------------------------
# Series:  postcode
# -----------------------------
# count    3999.000000
# mean     2985.755939
# std       844.878364
# min      2000.000000
# 25%      2200.000000
# 50%      2768.000000
# 75%      3750.000000
# max      4883.000000
# Name: postcode, dtype: float64
#
#
# -----------------------------
# Series:  property_valuation
# -----------------------------
# count    3999.000000
# mean        7.514379
# std         2.824663
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        10.000000
# max        12.000000
# Name: property_valuation, dtype: float64

# %% [markdown]
# Notes:
#
# Customer ID (customer_id):
#
# Count: 3,999 entries.
# Mean (average) customer ID: 2003.99.
# Standard deviation: 1,154.58.
# Minimum customer ID: 1.
# Maximum customer ID: 4,003.
#
# Postcode (postcode):
#
# Count: 3,999 entries.
# Mean (average) postcode: 2985.76.
# Standard deviation: 844.88.
# Minimum postcode: 2000.
# Maximum postcode: 4883.
#
# Property Valuation (property_valuation):
#
# Count: 3,999 entries.
# Mean (average) property valuation: 7.51.
# Standard deviation: 2.82.
# Minimum property valuation: 1.
# Maximum property valuation: 12.

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df1.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost                 time_difference
# count   19803.000000                           19803
# mean      556.046951  -4716 days +02:57:30.022723904
# std       405.955660    2876 days 02:24:50.135323296
# min         7.210000            -9838 days +00:00:00
# ...

# %%
df2.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
df3.describe()
# Out:
#        customer_id     postcode  property_valuation
# count  3999.000000  3999.000000         3999.000000
# mean   2003.987997  2985.755939            7.514379
# std    1154.576912   844.878364            2.824663
# min       1.000000  2000.000000            1.000000
# 25%    1004.500000  2200.000000            6.000000
# 50%    2004.000000  2768.000000            8.000000
# 75%    3003.500000  3750.000000           10.000000
# max    4003.000000  4883.000000           12.000000

# %%
print('transaction_id :')
print('-----------------------------')
print(df1['transaction_id'].describe())
print('-----------------------------')

print('product_id :')
print('-----------------------------')
print(df1['product_id'].describe())
print('-----------------------------')

print('customer_id :')
print('-----------------------------')
print(df1['customer_id'].describe())
print('-----------------------------')

print('transaction_date :')
print('-----------------------------')
print(df1['transaction_date'].describe())
print('-----------------------------')

print('online_order :')
print('-----------------------------')
print(df1['online_order'].describe())
print('-----------------------------')

print('order_status :')
print('-----------------------------')
print(df1['order_status'].describe())
print('-----------------------------')

print('brand :')
print('-----------------------------')
print(df1['brand'].describe())
print('-----------------------------')

print('product_line :')
print('-----------------------------')
print(df1['product_line'].describe())
print('-----------------------------')

print('product_class :')
print('-----------------------------')
print(df1['product_class'].describe())
print('-----------------------------')

print('product_size :')
print('-----------------------------')
print(df1['product_size'].describe())
print('-----------------------------')

print('list_price :')
print('-----------------------------')
print(df1['list_price'].describe())
print('-----------------------------')

print('standard_cost :')
print('-----------------------------')
print(df1['standard_cost'].describe())
print('-----------------------------')

print('product_first_sold_date :')
print('-----------------------------')
print(df1['product_first_sold_date'].describe())
print('-----------------------------')
# Out:
# transaction_id :
# -----------------------------
# count    20000.000000
# mean     10000.500000
# std       5773.647028
# min          1.000000
# 25%       5000.750000
# 50%      10000.500000
# 75%      15000.250000
# max      20000.000000
# Name: transaction_id, dtype: float64
# -----------------------------
# product_id :
# -----------------------------
# count    20000.00000
# mean        45.36465
# std         30.75359
# min          0.00000
# 25%         18.00000
# 50%         44.00000
# 75%         72.00000
# max        100.00000
# Name: product_id, dtype: float64
# -----------------------------
# customer_id :
# -----------------------------
# count    20000.000000
# mean      1738.246050
# std       1011.951046
# min          1.000000
# 25%        857.750000
# 50%       1736.000000
# 75%       2613.000000
# max       5034.000000
# Name: customer_id, dtype: float64
# -----------------------------
# transaction_date :
# -----------------------------
# ...

# %% [markdown]
# Observation of df1:
#
# Transaction ID (transaction_id):
#
# Counts from 1 to 20,000.
# Mean is around 10,000.5.
# Standard deviation is approximately 5,773.65.
#
# Product ID (product_id):
#
# Ranges from 0 to 100.
# Mean is approximately 45.36.
# Standard deviation is roughly 30.75.
#
# Customer ID (customer_id):
#
# Customer IDs ranging from 1 to 5,034.
# The mean customer ID is about 1,738.25.
# The standard deviation is approximately 1,011.95.
#
# Transaction Date (transaction_date):
#
# The dataset spans transactions from January 1, 2017, to December 30, 2017.
# The most frequent transaction date is February 14, 2017.
#
# Online Order (online_order):
#
# Binary variable indicating whether the order was placed online.
# 0 represents 'No,' and 1 represents 'Yes.'
# About half of the transactions were online orders.
#
# Order Status (order_status):
#
# Two unique values: 'Approved' and 'Cancelled.'
# Most orders are 'Approved.'
#
# Brand (brand):
#
# Six unique brands.
# 'Solex' is the most frequent brand.
#
# Product Line (product_line):
#
# Four unique product lines.
# 'Standard' is the most frequent product line.
#
# Product Class (product_class):
#
# Three unique product classes.
# 'Medium' is the most frequent product class.
#
# Product Size (product_size):
#
# Three unique product sizes.
# 'Medium' is the most frequent product size.
#
# List Price (list_price):
#
# List prices range from $12.01 to $2,091.47.
# The mean list price is approximately $1,107.83.
#
# Standard Cost (standard_cost):
#
# Standard costs range from $7.21 to $1,759.85.
# The mean standard cost is around $556.05.
#
# Product First Sold Date (product_first_sold_date):
#
# The dataset contains product first sold dates spanning from January 23, 1991, to December 8, 2016.
# The most frequent first sold date is October 4, 1992.

# %%
print('customer_id :')
print('-----------------------------')
print(df2['customer_id'].describe())
print('-----------------------------')


print('first_name :')
print('-----------------------------')
print(df2['first_name'].describe())
print('-----------------------------')


print('last_name :')
print('-----------------------------')
print(df2['last_name'].describe())
print('-----------------------------')


print('gender :')
print('-----------------------------')
print(df2['gender'].describe())
print('-----------------------------')


print('past_3_years_bike_related_purchases :')
print('-----------------------------')
print(df2['past_3_years_bike_related_purchases'].describe())
print('-----------------------------')


print('DOB :')
print('-----------------------------')
print(df2['DOB'].describe())
print('-----------------------------')


print('job_title :')
print('-----------------------------')
print(df2['job_title'].describe())
print('-----------------------------')


print('job_industry_category :')
print('-----------------------------')
print(df2['job_industry_category'].describe())
print('-----------------------------')


print('wealth_segment :')
print('-----------------------------')
print(df2['wealth_segment'].describe())
print('-----------------------------')


print('deceased_indicator :')
print('-----------------------------')
print(df2['deceased_indicator'].describe())
print('-----------------------------')


print('default :')
print('-----------------------------')
print(df2['default'].describe())
print('-----------------------------')


print('owns_car :')
print('-----------------------------')
print(df2['owns_car'].describe())
print('-----------------------------')


print('tenure :')
print('-----------------------------')
print(df2['tenure'].describe())
print('-----------------------------')
# Out:
# customer_id :
# -----------------------------
# count    4000.000000
# mean     2000.500000
# std      1154.844867
# min         1.000000
# 25%      1000.750000
# 50%      2000.500000
# 75%      3000.250000
# max      4000.000000
# Name: customer_id, dtype: float64
# -----------------------------
# first_name :
# -----------------------------
# count     4000
# unique    3139
# top        Max
# freq         5
# Name: first_name, dtype: object
# -----------------------------
# last_name :
# -----------------------------
# count         3875
# unique        3725
# top       Pristnor
# freq             3
# Name: last_name, dtype: object
# -----------------------------
# gender :
# -----------------------------
# count       4000
# unique         6
# top       Female
# freq        2037
# Name: gender, dtype: object
# -----------------------------
# past_3_years_bike_related_purchases :
# -----------------------------
# count    4000.000000
# mean       48.890000
# std        28.715005
# ...

# %% [markdown]
# Observations of df2:
#
# Customer ID (customer_id):
#
# Counts from 1 to 4,000.
# Mean is 2,000.5, indicating evenly distributed customer IDs.
# Standard deviation is approximately 1,154.84.
#
# First Name (first_name):
#
# 3,139 unique first names.
# 'Max' is the most frequent first name, occurring 5 times.
#
# Last Name (last_name):
#
# 3,725 unique last names.
# 'Pristnor' is the most frequent last name, occurring 3 times.
#
# Gender (gender):
#
# 6 unique gender categories.
# 'Female' is the most frequent gender, occurring 2,037 times.
#
# Past 3 Years Bike-Related Purchases (past_3_years_bike_related_purchases):
#
# Ranges from 0 to 99.
# Mean is approximately 48.89.
# Standard deviation is about 28.72.
#
# Date of Birth (DOB):
#
# 3,448 unique date of birth values.
# The earliest date of birth is December 21, 1843- it seems like this value is typo error for DOB will do research in data cleaning.
# The latest date of birth is March 11, 2002.
# '1978-01-30' is the most frequent date of birth, occurring 7 times.
#
# Job Title (job_title):
#
# 195 unique job titles.
# 'Business Systems Development Analyst' is the most frequent job title, occurring 45 times.
#
# Job Industry Category (job_industry_category):
#
# 9 unique industry categories.
# 'Manufacturing' is the most frequent industry category, occurring 799 times.
#
# Wealth Segment (wealth_segment):
#
# 3 unique wealth segments.
# 'Mass Customer' is the most frequent wealth segment, occurring 2,000 times.
#
# Deceased Indicator (deceased_indicator):
#
# Binary variable indicating whether a customer is deceased.
# 'N' represents 'No' (3998 occurrences).
# 'Y' represents 'Yes' (2 occurrences).
#
# Default (default):
#
# 90 unique default values.
# '100' is the most frequent default value, occurring 113 times.
#
# Owns Car (owns_car):
#
# Binary variable indicating whether a customer owns a car.
# 'Yes' indicates car ownership (2,024 occurrences).
# 'No' indicates no car ownership (1,976 occurrences).
#
# Tenure (tenure):
#
# Ranges from 1 to 22.
# Mean is approximately 10.66.
# Standard deviation is roughly 5.66.

# %%
print('customer_id :')
print('-----------------------------')
print(df3['customer_id'].describe())
print('-----------------------------')

print('address :')
print('-----------------------------')
print(df3['address'].describe())
print('-----------------------------')

print('postcode :')
print('-----------------------------')
print(df3['postcode'].describe())
print('-----------------------------')

print('state :')
print('-----------------------------')
print(df3['state'].describe())
print('-----------------------------')

print('country :')
print('-----------------------------')
print(df3['country'].describe())
print('-----------------------------')

print('property_valuation :')
print('-----------------------------')
print(df3['property_valuation'].describe())
print('-----------------------------')
# Out:
# customer_id :
# -----------------------------
# count    3999.000000
# mean     2003.987997
# std      1154.576912
# min         1.000000
# 25%      1004.500000
# 50%      2004.000000
# 75%      3003.500000
# max      4003.000000
# Name: customer_id, dtype: float64
# -----------------------------
# address :
# -----------------------------
# count                        3999
# unique                       3996
# top       3 Mariners Cove Terrace
# freq                            2
# Name: address, dtype: object
# -----------------------------
# postcode :
# -----------------------------
# count    3999.000000
# mean     2985.755939
# std       844.878364
# min      2000.000000
# 25%      2200.000000
# 50%      2768.000000
# 75%      3750.000000
# max      4883.000000
# Name: postcode, dtype: float64
# -----------------------------
# state :
# -----------------------------
# count     3999
# unique       5
# top        NSW
# freq      2054
# Name: state, dtype: object
# ...

# %% [markdown]
# Observations:
#
# customer_id:
#
# Count: 3,999
# Mean: 2,003.99 (approximately)
# Standard Deviation: 1,154.58 (approximately)
# Min: 1
# Max: 4,003
# Observation: This column contains unique customer IDs ranging from 1 to 3,999. The IDs are evenly distributed with a mean close to the midpoint.
#
# address:
#
# Count: 3,999
# Unique: 3,996
# Top: "3 Mariners Cove Terrace" (appears twice)
# Observation: There are 3,996 unique addresses, indicating some duplicate addresses in the dataset. "3 Mariners Cove Terrace" is the most frequent address, appearing twice.
#
# postcode:
#
# Count: 3,999
# Mean: 2,985.76 (approximately)
# Standard Deviation: 844.88 (approximately)
# Min: 2,000
# Max: 4,883
# Observation: Postal codes range from 2,000 to 4,883 with a mean around 2,985.76. There is a relatively wide spread in postal code values.
#
# state:
#
# Count: 3,999
# Unique: 5
# Top: "NSW"
# Frequency of "NSW": 2,054
# Observation: The most common state is New South Wales (NSW), appearing 2,054 times in the dataset. There are a total of five unique states.
#
# country:
#
# Count: 3,999
# Unique: 1 ("Australia")
# Observation: All entries in this column indicate "Australia," meaning that the data pertains to a single country.
#
# property_valuation:
#
# Count: 3,999
# Mean: 7.51 (approximately)
# Standard Deviation: 2.82 (approximately)
# Min: 1
# Max: 12
# Observation: Property valuation values range from 1 to 12, with an average valuation of approximately 7.51. The standard deviation suggests some variability in property valuations.

# %%
df1.hist(figsize=(15,12))
# Out:
# array([[<AxesSubplot:title={'center':'transaction_id'}>,
#         <AxesSubplot:title={'center':'product_id'}>,
#         <AxesSubplot:title={'center':'customer_id'}>],
#        [<AxesSubplot:title={'center':'transaction_date'}>,
#         <AxesSubplot:title={'center':'online_order'}>,
#         <AxesSubplot:title={'center':'list_price'}>],
#        [<AxesSubplot:title={'center':'standard_cost'}>,
#         <AxesSubplot:title={'center':'product_first_sold_date'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
df2.hist(figsize=(15,12))
# Out:
# array([[<AxesSubplot:title={'center':'customer_id'}>,
#         <AxesSubplot:title={'center':'past_3_years_bike_related_purchases'}>],
#        [<AxesSubplot:title={'center':'DOB'}>,
#         <AxesSubplot:title={'center':'tenure'}>]], dtype=object)

# %%
df3.hist(figsize=(15,12))
# Out:
# array([[<AxesSubplot:title={'center':'customer_id'}>,
#         <AxesSubplot:title={'center':'postcode'}>],
#        [<AxesSubplot:title={'center':'property_valuation'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
# list_price & standard_cost is much correlating and is closer to one. 
df1.corr()
# Out:
#                          transaction_id  product_id  customer_id  \
# transaction_id                 1.000000   -0.011486     0.001753
# product_id                    -0.011486    1.000000     0.004278
# customer_id                    0.001753    0.004278     1.000000
# online_order                   0.003394   -0.004233     0.001616
# list_price                    -0.006154    0.090066     0.009306
# standard_cost                 -0.003291    0.038765     0.005365
# product_first_sold_date        0.004835   -0.052961    -0.001521
#
#                          online_order  list_price  standard_cost  \
# transaction_id               0.003394   -0.006154      -0.003291
# product_id                  -0.004233    0.090066       0.038765
# customer_id                  0.001616    0.009306       0.005365
# online_order                 1.000000   -0.000295       0.006934
# list_price                  -0.000295    1.000000       0.551539
# ...

# %%
import seaborn as sns
# data_frame1=df1.corr()
# sns.heatmap(data_frame1, annot=True)

# Calculate the correlation matrix
data_frame1 = df1.corr()

# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data_frame1, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
# data_frame2=df2.corr()
# sns.heatmap(data_frame2, annot=True)

# Calculate the correlation matrix
data_frame1 = df2.corr()

# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data_frame1, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# import seaborn as sns
# data_frame3=df3.corr()
# sns.heatmap(data_frame3, annot=True)

# Calculate the correlation matrix
data_frame1 = df3.corr()

# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(data_frame1, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# # Plot list_price
# plt.figure(figsize=(5,5))
# sns.countplot(x='transaction_id', data=df1)
# plt.xticks(rotation=45)
# plt.show()

unique_brands = df1['brand'].unique()
chart = sns.countplot(x=df1['brand'])
chart.set_xticks(range(len(unique_brands)))
chart.set_xticklabels(labels=unique_brands, rotation=90)
plt.show()

# %%
unique_product_line = df1['product_line'].unique()
chart = sns.countplot(x=df1['product_line'])
chart.set_xticks(range(len(unique_product_line)))
chart.set_xticklabels(labels=unique_product_line, rotation=90)
plt.show()

# %%
unique_order_status = df1['order_status'].unique()
chart = sns.countplot(x=df1['order_status'])
chart.set_xticks(range(len(unique_order_status)))
chart.set_xticklabels(labels=unique_order_status, rotation=90)
plt.show()

# %%
unique_product_class = df1['product_class'].unique()
chart = sns.countplot(x=df1['product_class'])
chart.set_xticks(range(len(unique_product_class)))
chart.set_xticklabels(labels=unique_product_class, rotation=90)
plt.show()

# %%
unique_product_size = df1['product_size'].unique()
chart = sns.countplot(x=df1['product_size'])
chart.set_xticks(range(len(unique_product_size)))
chart.set_xticklabels(labels=unique_product_size, rotation=90)
plt.show()

# %%
# # Create a scatter plot
sns.scatterplot(data=df1, x='list_price', y='standard_cost')
plt.xlabel('list_price')
plt.ylabel('standard_cost')
plt.title('Scatter Plot of list_price, standard_cost')
plt.show()

# # Create a bar plot
# plt.figure(figsize=(10, 6))
# sns.barplot(data=df1, x='list_price', y='standard_cost', ci=None)
# plt.xlabel('list_price')
# plt.ylabel('standard_cost')
# plt.title('Average List Price by Brand')
# plt.xticks(rotation=45)
# plt.show()

# # Create a box plot
# plt.figure(figsize=(10, 6))
# sns.boxplot(data=df1, x='standard_cost', y='list_price')
# plt.xlabel('standard_cost')
# plt.ylabel('list_Price')
# plt.title('Distribution of standard_cost by list_Price')
# plt.xticks(rotation=400)
# plt.show()

# %%
# Create a line plot
sns.lineplot(data=df1, x='transaction_date', y='product_first_sold_date')
plt.xlabel('transaction_date')
plt.ylabel('product_first_sold_date')
plt.title('Line Plot of transaction_date, product_first_sold_date')
plt.show()

# %%
# sns.lineplot(data=df1, x='customer_id', y='brand')
# plt.xlabel('customer_id')
# plt.ylabel('brand')
# plt.title('Line Plot of customer_id, brand')
# plt.show()

# # Create a histogram
# sns.histplot(data=df1, x='list_price', bins=10)
# plt.xlabel('list_price')
# plt.ylabel('brand')
# plt.title('Histogram of list_price, brand')
# plt.show()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=df1, x='brand', y='list_price', ci=None)
plt.xlabel('brand')
plt.ylabel('list_price')
plt.title('Average List Price by Brand')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Conclusion:
#
# DataFrame 1 (df1):
# Transaction Data: This dataset appears to contain information related to transactions, including details about products, customers, and sales.
# Key Insights:
# There are a total of 20,000 transactions in this dataset.
# It includes information about customers, products, transaction dates, and more.
# There are some missing values in columns like product_first_sold_date and standard_cost.
# It seems to be primarily focused on product sales, with information on customer demographics linked through customer_id.
#
# DataFrame 2 (df2):
# Customer Demographic Data: This dataset appears to contain customer demographic information such as age, gender, job, and location.
# Key Insights:
# It contains 4,000 customer records.
# Some columns have missing data, like DOB and job_title.
# The DOB column has some unusual values, such as a minimum year of 1843, which might be a data quality issue or typo.
# It includes information on the gender, job titles, and other demographics of the customers.
#
# DataFrame 3 (df3):
# Customer Address Data: This dataset appears to contain customer address information, including their addresses, postcodes, and property valuations.
# Key Insights:
# There are 3,999 customer records in this dataset.
# It provides details about customer addresses and property valuations.
# There's only one unique value for country, which is "Australia."
# It might be used for location-based analysis or segmentation of customers.
